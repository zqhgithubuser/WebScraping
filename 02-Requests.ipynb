# %% [markdown]
# ## 基本使用

# %%
import requests

link = "https://requests.readthedocs.io/"
response = requests.get(link)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'https://requests.readthedocs.io/en/latest/'

# %%
response.history
# Out:
# [<Response [302]>]

# %% [markdown]
# ## 请求/响应头

# %%
response.request.headers
# Out:
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Cookie': '_cfuvid=CMaMSpJRcdnesprlmAcm_wtunrQ823gCPrc9y.tlrMc-1728539317182-0.0.1.1-604800000'}

# %%
response.headers
# Out:
# {'Date': 'Thu, 10 Oct 2024 05:48:37 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'CF-Ray': '8d04528d7bf87d2e-HKG', 'CF-Cache-Status': 'HIT', 'Access-Control-Allow-Origin': '*', 'Age': '1095', 'Cache-Control': 'max-age=1200', 'Content-Encoding': 'gzip', 'ETag': 'W/"7c5977ffb77321307e58ef20fa23fe2c"', 'Last-Modified': 'Wed, 29 May 2024 15:37:24 GMT', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'Vary': 'Accept-Encoding', 'access-control-allow-methods': 'HEAD, OPTIONS, GET', 'cdn-cache-control': 'public', 'referrer-policy': 'no-referrer-when-downgrade', 'x-amz-id-2': 'VtGqcKCIGNYzkU9610c8us08Ls9HZq9n6+/K3vMQnC4z9odAPdcsLUPiw66PgYj8sCPUFC1v4fo=', 'x-amz-meta-mtime': '1716997016.109503901', 'x-amz-request-id': 'SSGGP2RQB82NPGWA', 'x-amz-server-side-encryption': 'AES256', 'x-backend': 'web-ext-theme-i-025b208a8f266cf19', 'x-content-type-options': 'nosniff', 'x-rtd-domain': 'requests.readthedocs.io', 'x-rtd-force-addons': 'true', 'x-rtd-path': '/proxito/html/requests/latest/index.html', 'x-rtd-project': 'requests', 'x-rtd-project-method': 'public_domain', 'x-rtd-resolver-filename': '/', 'x-rtd-version': 'latest', 'x-rtd-version-method': 'path', 'x-served': 'Nginx-Proxito-Sendfile', 'Server': 'cloudflare', 'alt-svc': 'h3=":443"; ma=86400'}

# %% [markdown]
# ## Cookies/会话

# %%
response.cookies
# Out:
# <RequestsCookieJar[]>

# %%
session_obj = requests.session()
response_obj = session_obj.get('https://httpbin.org/cookies', cookies={'name': 'zqh', 'date': '07-Oct-2024'})
response_obj.text
# Out:
# '{\n  "cookies": {\n    "date": "07-Oct-2024", \n    "name": "zqh"\n  }\n}\n'

# %%
response_obj.headers
# Out:
# {'Date': 'Thu, 10 Oct 2024 05:57:02 GMT', 'Content-Type': 'application/json', 'Content-Length': '69', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
response_test = session_obj.get('https://httpbin.org/cookies')
response_test.text
# Out:
# '{\n  "cookies": {}\n}\n'

# %% [markdown]
# ## 响应内容

# %%
with open("downloads/test.html", "wb") as fp:
    fp.write(response.content)

# %% [markdown]
# ## GET方法

# %%
url = 'http://httpbin.org/get'
queries = {'q': 'method'}
response = requests.get(url, params=queries)
response.url
# Out:
# 'http://httpbin.org/get?q=method'

# %% [markdown]
# ## POST方法

# %%
pageUrl = 'http://httpbin.org/forms/post'
postUrl = 'http://httpbin.org/post'
params = {
    'customer': 'Mr Anish',
    'custtel': '',
    'custemail': 'anish@anishchapagain.com',
    'size': 'medium',
    'topping': ['cheese', 'mushroom'],
    'delivery': '14:45',
    'comments':'No comments'
}
headers = {'accept': 'text/html, */*', 'Referer': pageUrl}
response = requests.post(postUrl, data=params, headers=headers).json()
response
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'comments': 'No comments',
#   'custemail': 'anish@anishchapagain.com',
#   'customer': 'Mr Anish',
#   'custtel': '',
#   'delivery': '14:45',
#   'size': 'medium',
#   'topping': ['cheese', 'mushroom']},
#  'headers': {'Accept': 'text/html, */*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '145',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'Referer': 'http://httpbin.org/forms/post',
#   'User-Agent': 'python-requests/2.31.0',
#   'X-Amzn-Trace-Id': 'Root=1-67076ff1-41b38c34679e181d40276a9f'},
#  'json': None,
#  'origin': '120.239.20.10',
#  'url': 'http://httpbin.org/post'}
